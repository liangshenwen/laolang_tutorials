# %%
# %matplotlib inline

# %%
import matplotlib as plot
import numpy as np
import pandas as pd

# %%
# 日本对外出口的贸易额变化情况（单位，亿日元）

data_df = pd.DataFrame(data = {
    '2000':[516.542, 153.559,32.744, 33.088], 
    '2005':[656.565, 148.055, 88.369, 51.460],
    '2010':[673.996, 103.740, 130.856, 54.602],
    '2015':[756.139, 152.246, 132.234, 53.266],
    '2018':[814.788, 154.702, 158.977, 57.926]}, dtype=np.float32, index=['总额','美国','中国','韩国'])
data_df
# Out:
#           2000        2005        2010        2015        2018
# 总额  516.541992  656.565002  673.995972  756.138977  814.788025
# 美国  153.559006  148.054993  103.739998  152.246002  154.701996
# 中国   32.743999   88.369003  130.856003  132.233994  158.977005
# 韩国   33.088001   51.459999   54.602001   53.265999   57.925999

# %%
data_df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
data_df1 = data_df.transpose()
data_df1
# Out:
#               总额          美国          中国         韩国
# 2000  516.541992  153.559006   32.743999  33.088001
# 2005  656.565002  148.054993   88.369003  51.459999
# 2010  673.995972  103.739998  130.856003  54.602001
# 2015  756.138977  152.246002  132.233994  53.265999
# 2018  814.788025  154.701996  158.977005  57.925999

# %%
data_df1.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
help(data_df.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...
