# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/visualization.html#box-plots
#
# 箱形图又称为盒须图、盒式图、盒状图或箱线图，是一种用作显示一组数据分散情况资料的统计图。因型状如箱子而得名。在各种领域也经常被使用，常见于品质管理，快速识别异常值。箱形图最大的优点就是不受异常值的影响，能够准确稳定地描绘出数据的离散分布情况，同时也利于数据的清洗。箱形图不受异常值的影响，这很重要。
#
# https://blog.csdn.net/qq_39543984/article/details/120398152
#
# ![image.png](attachment:647f97eb-126e-4de2-861e-f4ef4393e828.png)

# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])
df
# Out:
#           A         B         C         D         E
# 0  0.165495  0.915636  0.418758  0.576488  0.113601
# 1  0.422095  0.133527  0.563112  0.575558  0.064305
# 2  0.903189  0.565690  0.661412  0.565763  0.728107
# 3  0.116855  0.478887  0.587608  0.711247  0.909414
# 4  0.090680  0.207054  0.556322  0.750705  0.785492
# 5  0.658548  0.027129  0.404020  0.010142  0.644988
# 6  0.724056  0.979832  0.352519  0.105465  0.811726
# 7  0.276431  0.841840  0.664525  0.194373  0.578915
# 8  0.390388  0.819420  0.653864  0.253322  0.585121
# 9  0.737807  0.601732  0.634457  0.225554  0.151550

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
color = {
    "boxes": "DarkGreen",
    "whiskers": "DarkOrange",
    "medians": "DarkBlue",
    "caps": "Gray",
}


df.plot.box(color=color, sym="r+")
# Out:
# <AxesSubplot:>

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=["Col1", "Col2"])

df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])

df
# Out:
#        Col1      Col2  X
# 0  0.095258  0.496682  A
# 1  0.397428  0.053676  A
# 2  0.150824  0.947338  A
# 3  0.743428  0.232835  A
# 4  0.768044  0.357595  A
# 5  0.897199  0.384225  B
# 6  0.113447  0.657003  B
# 7  0.945882  0.578312  B
# 8  0.460317  0.361115  B
# 9  0.767533  0.968786  B

# %%
bp = df.boxplot(by="X")

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=["Col1", "Col2", "Col3"])

df["X"] = pd.Series(["A", "A", "A", "A", "A", "B", "B", "B", "B", "B"])

df["Y"] = pd.Series(["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"])

df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.565653  0.430929  0.767489  A  A
# 1  0.802804  0.228542  0.380999  A  B
# 2  0.643565  0.240065  0.149707  A  A
# 3  0.593544  0.989556  0.640495  A  B
# 4  0.721406  0.701530  0.362718  A  A
# 5  0.762269  0.315275  0.130482  B  B
# 6  0.635339  0.138298  0.611813  B  A
# 7  0.284933  0.064652  0.197095  B  B
# 8  0.227501  0.375770  0.737928  B  A
# 9  0.503231  0.937573  0.534511  B  B

# %%
bp = df.boxplot(column=["Col1", "Col2"], by=["X", "Y"])

# %%
np.random.seed(1234)

df_box = pd.DataFrame(np.random.randn(50, 2))

df_box["g"] = np.random.choice(["A", "B"], size=50)

df_box.loc[df_box["g"] == "B", 1] += 10

df_box
# Out:
#            0          1  g
# 0   0.471435  -1.190976  A
# 1   1.432707  -0.312652  A
# 2  -0.720589  10.887163  B
# 3   0.859588  -0.636524  A
# 4   0.015696   7.757315  B
# 5   1.150036   0.991946  A
# 6   0.953324  -2.021255  A
# 7  -0.334077   0.002118  A
# 8   0.405453   0.289092  A
# 9   1.321158  -1.546906  A
# 10 -0.202646   9.344031  B
# 11  0.193421  10.553439  B
# 12  1.318152   9.530695  B
# 13  0.675554   8.182973  B
# 14 -0.183109  11.058969  B
# 15 -0.397840   0.337438  A
# 16  1.047579  11.045938  B
# 17  0.863717   9.877908  B
# 18  0.124713   9.677205  B
# 19  0.841675  12.390961  B
# 20  0.076200  -0.566446  A
# 21  0.036142   7.925022  B
# 22  0.247792   9.102843  B
# 23 -0.136795  10.018289  B
# 24  0.755414  10.215269  B
# 25  0.841009   8.554190  B
# 26 -1.401973  -0.100918  A
# 27 -0.548242   9.855380  B
# 28  0.354020   9.964487  B
# 29  0.565738   1.545659  A
# 30 -0.974236   9.929655  B
# 31  0.307969  -0.208499  A
# 32  1.033801  -2.400454  A
# ...

# %%
bp = df_box.boxplot(by="g")

# %%
df_box.groupby("g").boxplot()
# Out:
# A         AxesSubplot(0.1,0.15;0.363636x0.75)
# B    AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %%
df_box.groupby("g")
