# %% [markdown]
# # 引入python依赖库

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

import notebook_helper as nbhelper

pd.set_option('display.max_rows', 30)

# %%
plt.matplotlib_fname()
# Out:
# 'C:\\my_python_world\\Python310\\lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %% [markdown]
# # 985大学

# %%
university_985_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='985大学')
university_985_df
# Out:
#     排名        名称 所在地 生源质量分
# 0    1      清华大学  北京   100
# 1    2      北京大学  北京  96.4
# 2    3  中国科学技术大学  安徽  92.1
# 3    4      复旦大学  上海  91.5
# 4    5    中国人民大学  北京  90.8
# ..  ..       ...  ..   ...
# 34  35    中央民族大学  北京  69.8
# 35  36      东北大学  辽宁    69
# 36  37      兰州大学  甘肃  68.7
# 37  38  西北农林科技大学  陕西  62.1
# 38  暂无    国防科技大学  湖南    暂无
#
# [39 rows x 4 columns]

# %%
area_dist_985_df = university_985_df[['名称', '所在地']].groupby(by=['所在地']).count()
area_dist_985_df.plot(kind='barh', title='985 - 大学区域分布', xticks = range(0, area_dist_985_df.max()[0] + 1), xlabel='区域', figsize=(25,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'985 - 大学区域分布'}, ylabel='区域'>

# %% [markdown]
# # 211大学

# %%
university_211_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='211大学')
university_211_df
# Out:
#      排名        名称 所在地 生源质量分
# 0     1      清华大学  北京   100
# 1     2      北京大学  北京  96.4
# 2     3  中国科学技术大学  安徽  92.1
# 3     4      复旦大学  上海  91.5
# 4     5    中国人民大学  北京  90.8
# ..   ..       ...  ..   ...
# 110  暂无    国防科技大学  湖南    暂无
# 111  暂无    中央音乐学院  北京    暂无
# 112  暂无    第二军医大学  上海    暂无
# 113  暂无    第四军医大学  陕西    暂无
# 114  暂无      西藏大学  西藏    暂无
#
# [115 rows x 4 columns]

# %%
area_dist_211_df = university_211_df[['名称', '所在地']].groupby(by=['所在地']).count()
area_dist_211_df.plot(kind='barh', title='211 - 大学区域分布', xticks = range(0, area_dist_211_df.max()[0] + 1), xlabel='区域', figsize=(25,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'211 - 大学区域分布'}, ylabel='区域'>

# %% [markdown]
# # 双一流大学

# %%
university_fisrt_class_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='双一流大学')
university_fisrt_class_df
# Out:
#       序号       学校 所在地                                            双一流建设学科
# 0      1     北京大学  北京                                    （自主确定建设学科并自行公布）
# 1      2   中国人民大学  北京  哲学、理论经济学、应用经济学、法学、政治学、社会学、马克思主义理论、新闻传播学、中国史、统计...
# 2      3     清华大学  北京                                    （自主确定建设学科并自行公布）
# 3      4   北京交通大学  北京                                               系统科学
# 4      5   北京工业大学  北京                                               土木工程
# ..   ...      ...  ..                                                ...
# 141  143   上海科技大学  上海                                            材料科学与工程
# 142  144  中国科学院大学  北京                                         化学、材料科学与工程
# 143  145   国防科技大学  湖南            信息与通信工程、计算机科学与技术、航空宇航科学与技术、软件工程、管理科学与工程
# 144  146   海军军医大学  上海                                               基础医学
# 145  147   空军军医大学  陕西                                               临床医学
#
# [146 rows x 4 columns]

# %%
area_dist_first_class_df = university_fisrt_class_df[['学校', '所在地']].groupby(by=['所在地']).count()
area_dist_first_class_df.plot(kind='barh', title='双一流大学 - 大学区域分布', xticks = range(0, area_dist_first_class_df.max()[0] + 1), xlabel='区域', figsize=(25,10), grid=True)
# Out:
# <AxesSubplot:title={'center':'双一流大学 - 大学区域分布'}, ylabel='区域'>

# %% [markdown]
# # 985大学都是211大学

# %%
university_985_211_df = pd.merge(university_985_df, university_211_df, how='inner', on='名称')
university_985_211_df.rename(columns={'名称':'学校',
                                      '所在地_x':'所在地',
                                      '排名_x':'985排名', 
                                      '生源质量分_x':'985得分', 
                                      '排名_y':'211排名',
                                      '生源质量分_y':'211得分'
                                    }, inplace=True)
university_985_211_df = university_985_211_df.loc[:, ['学校','所在地','985排名','985得分','211排名','211得分']]
university_985_211_df
# Out:
#           学校 所在地 985排名 985得分 211排名 211得分
# 0       清华大学  北京     1   100     1   100
# 1       北京大学  北京     2  96.4     2  96.4
# 2   中国科学技术大学  安徽     3  92.1     3  92.1
# 3       复旦大学  上海     4  91.5     4  91.5
# 4     中国人民大学  北京     5  90.8     5  90.8
# ..       ...  ..   ...   ...   ...   ...
# 34    中央民族大学  北京    35  69.8    54  69.8
# 35      东北大学  辽宁    36    69    60    69
# 36      兰州大学  甘肃    37  68.7    61  68.7
# 37  西北农林科技大学  陕西    38  62.1    88  62.1
# 38    国防科技大学  湖南    暂无    暂无    暂无    暂无
#
# [39 rows x 6 columns]

# %% [markdown]
# # 211大学中比985好的

# %%
university_985_filter_df = university_985_df.replace('暂无', np.nan)
min_score_985 = university_985_filter_df['生源质量分'].min()
print('985最小分值', min_score_985)
university_985_filter_df[university_985_filter_df['生源质量分']==min_score_985]
# Out:
# 985最小分值 62.1
#       排名        名称 所在地  生源质量分
# 37  38.0  西北农林科技大学  陕西   62.1

# %%
university_211_filter_df = university_211_df.replace('暂无', np.nan)

university_211_filter_df = university_211_filter_df[(~university_211_filter_df['名称'].isin(university_985_filter_df['名称']))]
university_211_filter_df = university_211_filter_df[university_211_filter_df['生源质量分']>min_score_985]
university_211_filter_df = university_211_filter_df.astype({'排名': 'int32'})
university_211_filter_df
# Out:
#     排名        名称 所在地  生源质量分
# 9   10    上海财经大学  上海   86.2
# 12  13    中央财经大学  北京   85.2
# 15  16  对外经济贸易大学  北京   84.2
# 21  22   北京外国语大学  北京   81.8
# 23  24    中国政法大学  北京   80.8
# ..  ..       ...  ..    ...
# 82  83    陕西师范大学  陕西   63.3
# 83  84    南京农业大学  江苏   63.0
# 84  85    湖南师范大学  湖南   62.8
# 85  86      福州大学  福建   62.6
# 86  87    大连海事大学  辽宁   62.3
#
# [50 rows x 4 columns]

# %% [markdown]
# # 985大学中的双一流

# %%
university_985_first_class = pd.merge(university_985_df, university_fisrt_class_df, left_on='名称', right_on='学校')
university_985_first_class
# Out:
#     排名        名称 所在地_x 生源质量分   序号        学校 所在地_y  \
# 0    1      清华大学    北京   100    3      清华大学    北京
# 1    2      北京大学    北京  96.4    1      北京大学    北京
# 2    3  中国科学技术大学    安徽  92.1   83  中国科学技术大学    安徽
# 3    4      复旦大学    上海  91.5   51      复旦大学    上海
# 4    5    中国人民大学    北京  90.8    2    中国人民大学    北京
# ..  ..       ...   ...   ...  ...       ...   ...
# 34  35    中央民族大学    北京  69.8   28    中央民族大学    北京
# 35  36      东北大学    辽宁    69   42      东北大学    辽宁
# 36  37      兰州大学    甘肃  68.7  133      兰州大学    甘肃
# 37  38  西北农林科技大学    陕西  62.1  131  西北农林科技大学    陕西
# 38  暂无    国防科技大学    湖南    暂无  145    国防科技大学    湖南
#
#                                               双一流建设学科
# 0                                     （自主确定建设学科并自行公布）
# 1                                     （自主确定建设学科并自行公布）
# 2   数学、物理学、化学、天文学、地球物理学、生物学、科学技术史、材料科学与工程、计算机科学与技术...
# 3   哲学、应用经济学、政治学、马克思主义理论、中国语言文学、外国语言文学、中国史、数学、物理学、...
# 4   哲学、理论经济学、应用经济学、法学、政治学、社会学、马克思主义理论、新闻传播学、中国史、统计...
# ..                                                ...
# 34                                                民族学
# 35                                       冶金工程、控制科学与工程
# 36                                     化学、大气科学、生态学、草学
# 37                                           植物保护、畜牧学
# 38            信息与通信工程、计算机科学与技术、航空宇航科学与技术、软件工程、管理科学与工程
#
# [39 rows x 8 columns]

# %% [markdown]
# # 211大学中的双一流

# %%
university_211_first_class = pd.merge(university_211_df, university_fisrt_class_df, left_on='名称', right_on='学校')
university_211_first_class
# Out:
#       排名        名称 所在地_x 生源质量分   序号        学校 所在地_y  \
# 0      1      清华大学    北京   100    3      清华大学    北京
# 1      2      北京大学    北京  96.4    1      北京大学    北京
# 2      3  中国科学技术大学    安徽  92.1   83  中国科学技术大学    安徽
# 3      4      复旦大学    上海  91.5   51      复旦大学    上海
# 4      5    中国人民大学    北京  90.8    2    中国人民大学    北京
# ..   ...       ...   ...   ...  ...       ...   ...
# 108  109     石河子大学    新疆  40.6  137     石河子大学    新疆
# 109  110      青海大学    青海  36.9  134      青海大学    青海
# 110   暂无    国防科技大学    湖南    暂无  145    国防科技大学    湖南
# 111   暂无    中央音乐学院    北京    暂无   24    中央音乐学院    北京
# 112   暂无      西藏大学    西藏    暂无  125      西藏大学    西藏
#
#                                                双一流建设学科
# 0                                      （自主确定建设学科并自行公布）
# 1                                      （自主确定建设学科并自行公布）
# 2    数学、物理学、化学、天文学、地球物理学、生物学、科学技术史、材料科学与工程、计算机科学与技术...
# 3    哲学、应用经济学、政治学、马克思主义理论、中国语言文学、外国语言文学、中国史、数学、物理学、...
# 4    哲学、理论经济学、应用经济学、法学、政治学、社会学、马克思主义理论、新闻传播学、中国史、统计...
# ..                                                 ...
# 108                                            化学工程与技术
# 109                                                生态学
# 110            信息与通信工程、计算机科学与技术、航空宇航科学与技术、软件工程、管理科学与工程
# 111                                             音乐与舞蹈学
# 112                                                生态学
#
# [113 rows x 8 columns]

# %% [markdown]
# # 211大学包括计算机和软件学科

# %%
university_211_first_class_programming = university_211_first_class[university_211_first_class['双一流建设学科'].str.contains('计算机|软件|自主确定',regex=True)]
university_211_first_class_programming = university_211_first_class_programming[['排名', '名称', '所在地_x', '生源质量分','双一流建设学科']]
university_211_first_class_programming = university_211_first_class_programming.rename(columns={'所在地_x':'所在地'})
university_211_first_class_programming
# Out:
#       排名        名称  所在地 生源质量分  \
# 0      1      清华大学   北京   100
# 1      2      北京大学   北京  96.4
# 2      3  中国科学技术大学   安徽  92.1
# 5      6    上海交通大学   上海  90.5
# 6      7      南京大学   江苏  88.4
# 8      9      浙江大学   浙江  86.3
# 11    12  北京航空航天大学   北京  85.4
# 18    19    华中科技大学   湖北  82.4
# 20    21      东南大学   江苏  81.8
# 25    26   哈尔滨工业大学  黑龙江  78.2
# 26    27    北京邮电大学   北京  78.2
# 46    47  西安电子科技大学   陕西  72.2
# 106  107      新疆大学   新疆  44.2
# 110   暂无    国防科技大学   湖南    暂无
#
#                                                双一流建设学科
# 0                                      （自主确定建设学科并自行公布）
# 1                                      （自主确定建设学科并自行公布）
# 2    数学、物理学、化学、天文学、地球物理学、生物学、科学技术史、材料科学与工程、计算机科学与技术...
# 5    数学、物理学、化学、生物学、机械工程、材料科学与工程、电子科学与技术、信息与通信工程、控制科...
# 6    哲学、理论经济学、中国语言文学、外国语言文学、物理学、化学、天文学、大气科学、地质学、生物学...
# 8    化学、生物学、生态学、机械工程、光学工程、材料科学与工程、动力工程及工程热物理、电气工程、控...
# 11   力学、仪器科学与技术、材料科学与工程、控制科学与工程、计算机科学与技术、交通运输工程、航空宇...
# 18   机械工程、光学工程、材料科学与工程、动力工程及工程热物理、电气工程、计算机科学与技术、基础医...
# 20   机械工程、材料科学与工程、电子科学与技术、信息与通信工程、控制科学与工程、计算机科学与技术、...
# 25   力学、机械工程、材料科学与工程、控制科学与工程、计算机科学与技术、土木工程、航空宇航科学与技...
# 26                                    信息与通信工程、计算机科学与技术
# 46                                    信息与通信工程、计算机科学与技术
# 106                                马克思主义理论、化学、计算机科学与技术
# 110            信息与通信工程、计算机科学与技术、航空宇航科学与技术、软件工程、管理科学与工程

# %% [markdown]
# # 专业 - 人工智能 - 排名

# %%
university_ai_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='人工智能-排名')
university_ai_df.rename(columns={'序号':'人工智能-排名','评选结果':'人工智能-评选结果'}, inplace=True)
university_ai_df
# Out:
#     人工智能-排名   学校代码      学校名称 人工智能-评选结果
# 0         1  10614    电子科技大学        A+
# 1         2  10701  西安电子科技大学        A+
# 2         3  10001      北京大学         A
# 3         4  10003      清华大学         A
# 4         5  10286      东南大学         A
# ..      ...    ...       ...       ...
# 69       70  10356    中国计量大学        C-
# 70       71  10459      郑州大学        C-
# 71       72  10497    武汉理工大学        C-
# 72       73  10590      深圳大学        C-
# 73       74  10697      西北大学        C-
#
# [74 rows x 4 columns]

# %% [markdown]
# # 专业 - 物联网工程- 排名

# %%
university_iot_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='物联网工程-排名')
university_iot_df.rename(columns={'序号':'物联网工程-排名','评选结果':'物联网工程-评选结果'}, inplace=True)
university_iot_df
# Out:
#      物联网工程-排名   学校代码      学校名称 物联网工程-评选结果
# 0           1  10001      北京大学         A+
# 1           2  10003      清华大学         A+
# 2           3  10335      浙江大学         A+
# 3           4  90002    国防科技大学         A+
# 4           5  10006  北京航空航天大学          A
# ..        ...    ...       ...        ...
# 163       164  10254    上海海事大学         C-
# 164       165  10289    江苏科技大学         C-
# 165       166  10385      华侨大学         C-
# 166       167  10405    东华理工大学         C-
# 167       168  10407    江西理工大学         C-
#
# [168 rows x 4 columns]

# %% [markdown]
# # 专业 - 大数据管理与应用- 排名

# %%
university_big_data_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='大数据管理与应用-排名')
university_big_data_df.rename(columns={'序号':'大数据管理与应用-排名','评选结果':'大数据管理与应用-评选结果'}, inplace=True)
university_big_data_df
# Out:
#     大数据管理与应用-排名   学校代码      学校名称 大数据管理与应用-评选结果
# 0             1  10614    电子科技大学            A+
# 1             2  10701  西安电子科技大学            A+
# 2             3  10001      北京大学             A
# 3             4  10003      清华大学             A
# 4             5  10286      东南大学             A
# ..          ...    ...       ...           ...
# 69           70  10356    中国计量大学            C-
# 70           71  10459      郑州大学            C-
# 71           72  10497    武汉理工大学            C-
# 72           73  10590      深圳大学            C-
# 73           74  10697      西北大学            C-
#
# [74 rows x 4 columns]

# %% [markdown]
# # 专业 - 计算机科学与技术 - 排名

# %%
university_computer_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='计算机科学与技术-排名')
university_computer_df.rename(columns={'序号':'计算机科学与技术-排名','评选结果':'计算机科学与技术-评选结果'}, inplace=True)
university_computer_df
# Out:
#      计算机科学与技术-排名   学校代码               学校名称 计算机科学与技术-评选结果
# 0              1  10001               北京大学            A+
# 1              2  10003               清华大学            A+
# 2              3  10335               浙江大学            A+
# 3              4  91002             国防科技大学            A+
# 4              5  10006           北京航空航天大学             A
# ..           ...    ...                ...           ...
# 163          164  10651             西南财经大学            C-
# 164          165  10705             西安石油大学            C-
# 165          166  11232           北京信息科技大学            C-
# 166          167  11535             湖南工业大学            C-
# 167          168  91019  海军航空大学（原海军航空工程学院）            C-
#
# [168 rows x 4 columns]

# %% [markdown]
# # 专业 - 软件工程 - 排名

# %%
university_software_df = pd.read_excel('中国大学专业分析.xlsx', sheet_name='软件工程-排名')
university_software_df.rename(columns={'序号':'软件工程-排名','评选结果':'软件工程-评选结果'}, inplace=True)
university_software_df
# Out:
#      软件工程-排名   学校代码               学校名称 软件工程-评选结果
# 0          1  10006           北京航空航天大学        A+
# 1          2  10335               浙江大学        A+
# 2          3  90002             国防科技大学        A+
# 3          4  10001               北京大学         A
# 4          5  10003               清华大学         A
# ..       ...    ...                ...       ...
# 113      114  10623               西华大学        C-
# 114      115  10636             四川师范大学        C-
# 115      116  10674             昆明理工大学        C-
# 116      117  10710               长安大学        C-
# 117      118  90039  海军航空大学（原海军航空工程学院）        C-
#
# [118 rows x 4 columns]

# %% [markdown]
# # 综合专业排名

# %%
university_names_211 = university_211_df['名称']
university_names_985 = university_985_df['名称']
university_names_first_class = university_fisrt_class_df['学校']
university_major_df = pd.merge(university_software_df, university_computer_df, how='outer', on=['学校代码','学校名称'])
university_major_df = pd.merge(university_major_df, university_big_data_df, how='outer', on=['学校代码','学校名称'])
university_major_df = pd.merge(university_major_df, university_iot_df, how='outer', on=['学校代码','学校名称'])
university_major_df = pd.merge(university_major_df, university_ai_df, how='outer', on=['学校代码','学校名称'])
university_major_df['是否211大学'] = university_major_df['学校名称'].isin(university_names_211)
university_major_df['是否985大学'] = university_major_df['学校名称'].isin(university_names_985)
university_major_df['是否双一流大学'] = university_major_df['学校名称'].isin(university_names_first_class)
university_major_df
# Out:
#      软件工程-排名   学校代码      学校名称 软件工程-评选结果  计算机科学与技术-排名 计算机科学与技术-评选结果  \
# 0        1.0  10006  北京航空航天大学        A+          5.0             A
# 1        2.0  10335      浙江大学        A+          3.0            A+
# 2        3.0  90002    国防科技大学        A+          NaN           NaN
# 3        4.0  10001      北京大学         A          1.0            A+
# 4        5.0  10003      清华大学         A          2.0            A+
# ..       ...    ...       ...       ...          ...           ...
# 185      NaN  90045    空军工程大学       NaN          NaN           NaN
# 186      NaN  90006   解放军理工大学       NaN          NaN           NaN
# 187      NaN  10512      湖北大学       NaN          NaN           NaN
# 188      NaN  90039  海军航空工程学院       NaN          NaN           NaN
# 189      NaN  10356    中国计量大学       NaN          NaN           NaN
#
#      大数据管理与应用-排名 大数据管理与应用-评选结果  物联网工程-排名 物联网工程-评选结果  人工智能-排名 人工智能-评选结果  \
# 0           12.0            B+       5.0          A     12.0        B+
# 1           10.0            A-       3.0         A+     10.0        A-
# 2           20.0            B+       4.0         A+     20.0        B+
# 3            3.0             A       1.0         A+      3.0         A
# 4            4.0             A       2.0         A+      4.0         A
# ..           ...           ...       ...        ...      ...       ...
# 185         21.0            B+      95.0         B-     21.0        B+
# 186         42.0            B-      47.0         B+     42.0        B-
# 187         57.0             C       NaN        NaN     57.0         C
# 188         63.0             C     160.0         C-     63.0         C
# 189         70.0            C-       NaN        NaN     70.0        C-
#
#      是否211大学  是否985大学  是否双一流大学
# 0       True     True     True
# 1       True     True     True
# 2       True     True     True
# 3       True     True     True
# 4       True     True     True
# ..       ...      ...      ...
# 185    False    False    False
# 186    False    False    False
# 187    False    False    False
# 188    False    False    False
# 189    False    False    False
#
# [190 rows x 15 columns]

# %%
good_university_major_df = university_major_df[(university_major_df['是否211大学']==True)&(university_major_df['是否985大学']==True)&(university_major_df['是否双一流大学']==True)]
good_university_major_df = nbhelper.ahead_df_columns(good_university_major_df,['学校代码','学校名称'])
good_university_major_df.reset_index(inplace=True, drop=True)
good_university_major_df
# Out:
#      学校代码      学校名称  软件工程-排名 软件工程-评选结果  计算机科学与技术-排名 计算机科学与技术-评选结果  \
# 0   10006  北京航空航天大学      1.0        A+          5.0             A
# 1   10335      浙江大学      2.0        A+          3.0            A+
# 2   90002    国防科技大学      3.0        A+          NaN           NaN
# 3   10001      北京大学      4.0         A          1.0            A+
# 4   10003      清华大学      5.0         A          2.0            A+
# ..    ...       ...      ...       ...          ...           ...
# 35  10027    北京师范大学      NaN       NaN         48.0             B
# 36  10730      兰州大学      NaN       NaN         70.0             B
# 37  10019    中国农业大学      NaN       NaN         73.0            B-
# 38  10712  西北农林科技大学      NaN       NaN        138.0             C
# 39  10052    中央民族大学      NaN       NaN        143.0            C-
#
#     大数据管理与应用-排名 大数据管理与应用-评选结果  物联网工程-排名 物联网工程-评选结果  人工智能-排名 人工智能-评选结果  \
# 0          12.0            B+       5.0          A     12.0        B+
# 1          10.0            A-       3.0         A+     10.0        A-
# 2          20.0            B+       4.0         A+     20.0        B+
# 3           3.0             A       1.0         A+      3.0         A
# 4           4.0             A       2.0         A+      4.0         A
# ..          ...           ...       ...        ...      ...       ...
# 35          NaN           NaN      61.0          B      NaN       NaN
# 36         52.0            C+      59.0          B     52.0        C+
# 37          NaN           NaN      73.0         B-      NaN       NaN
# 38          NaN           NaN     138.0          C      NaN       NaN
# 39          NaN           NaN     161.0         C-      NaN       NaN
#
#     是否211大学  是否985大学  是否双一流大学
# 0      True     True     True
# 1      True     True     True
# 2      True     True     True
# 3      True     True     True
# 4      True     True     True
# ..      ...      ...      ...
# 35     True     True     True
# 36     True     True     True
# 37     True     True     True
# 38     True     True     True
# 39     True     True     True
#
# [40 rows x 15 columns]

# %%
nbhelper.highlight_columns(good_university_major_df[pd.notna(good_university_major_df['软件工程-评选结果'])].reset_index(),['软件工程-排名', '软件工程-评选结果'])
# Out:
# <style type="text/css">
# #T_91e54_row0_col3, #T_91e54_row0_col4, #T_91e54_row1_col3, #T_91e54_row1_col4, #T_91e54_row2_col3, #T_91e54_row2_col4, #T_91e54_row3_col3, #T_91e54_row3_col4, #T_91e54_row4_col3, #T_91e54_row4_col4, #T_91e54_row5_col3, #T_91e54_row5_col4, #T_91e54_row6_col3, #T_91e54_row6_col4, #T_91e54_row7_col3, #T_91e54_row7_col4, #T_91e54_row8_col3, #T_91e54_row8_col4, #T_91e54_row9_col3, #T_91e54_row9_col4, #T_91e54_row10_col3, #T_91e54_row10_col4, #T_91e54_row11_col3, #T_91e54_row11_col4, #T_91e54_row12_col3, #T_91e54_row12_col4, #T_91e54_row13_col3, #T_91e54_row13_col4, #T_91e54_row14_col3, #T_91e54_row14_col4, #T_91e54_row15_col3, #T_91e54_row15_col4, #T_91e54_row16_col3, #T_91e54_row16_col4, #T_91e54_row17_col3, #T_91e54_row17_col4, #T_91e54_row18_col3, #T_91e54_row18_col4, #T_91e54_row19_col3, #T_91e54_row19_col4, #T_91e54_row20_col3, #T_91e54_row20_col4, #T_91e54_row21_col3, #T_91e54_row21_col4, #T_91e54_row22_col3, #T_91e54_row22_col4, #T_91e54_row23_col3, #T_91e54_row23_col4, #T_91e54_row24_col3, #T_91e54_row24_col4, #T_91e54_row25_col3, #T_91e54_row25_col4, #T_91e54_row26_col3, #T_91e54_row26_col4, #T_91e54_row27_col3, #T_91e54_row27_col4, #T_91e54_row28_col3, #T_91e54_row28_col4, #T_91e54_row29_col3, #T_91e54_row29_col4, #T_91e54_row30_col3, #T_91e54_row30_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_91e54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91e54_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_91e54_level0_col1" class="col_heading level0 col1" >学校代码</th>
#       <th id="T_91e54_level0_col2" class="col_heading level0 col2" >学校名称</th>
#       <th id="T_91e54_level0_col3" class="col_heading level0 col3" >软件工程-排名</th>
#       <th id="T_91e54_level0_col4" class="col_heading level0 col4" >软件工程-评选结果</th>
#       <th id="T_91e54_level0_col5" class="col_heading level0 col5" >计算机科学与技术-排名</th>
#       <th id="T_91e54_level0_col6" class="col_heading level0 col6" >计算机科学与技术-评选结果</th>
#       <th id="T_91e54_level0_col7" class="col_heading level0 col7" >大数据管理与应用-排名</th>
#       <th id="T_91e54_level0_col8" class="col_heading level0 col8" >大数据管理与应用-评选结果</th>
#       <th id="T_91e54_level0_col9" class="col_heading level0 col9" >物联网工程-排名</th>
#       <th id="T_91e54_level0_col10" class="col_heading level0 col10" >物联网工程-评选结果</th>
#       <th id="T_91e54_level0_col11" class="col_heading level0 col11" >人工智能-排名</th>
#       <th id="T_91e54_level0_col12" class="col_heading level0 col12" >人工智能-评选结果</th>
#       <th id="T_91e54_level0_col13" class="col_heading level0 col13" >是否211大学</th>
#       <th id="T_91e54_level0_col14" class="col_heading level0 col14" >是否985大学</th>
#       <th id="T_91e54_level0_col15" class="col_heading level0 col15" >是否双一流大学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91e54_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91e54_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_91e54_row0_col1" class="data row0 col1" >10006</td>
#       <td id="T_91e54_row0_col2" class="data row0 col2" >北京航空航天大学</td>
#       <td id="T_91e54_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_91e54_row0_col4" class="data row0 col4" >A+</td>
#       <td id="T_91e54_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_91e54_row0_col6" class="data row0 col6" >A</td>
#       <td id="T_91e54_row0_col7" class="data row0 col7" >12.000000</td>
#       <td id="T_91e54_row0_col8" class="data row0 col8" >B+</td>
#       <td id="T_91e54_row0_col9" class="data row0 col9" >5.000000</td>
#       <td id="T_91e54_row0_col10" class="data row0 col10" >A</td>
#       <td id="T_91e54_row0_col11" class="data row0 col11" >12.000000</td>
#       <td id="T_91e54_row0_col12" class="data row0 col12" >B+</td>
#       <td id="T_91e54_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_91e54_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_91e54_row0_col15" class="data row0 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_91e54_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_91e54_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_91e54_row1_col1" class="data row1 col1" >10335</td>
#       <td id="T_91e54_row1_col2" class="data row1 col2" >浙江大学</td>
#       <td id="T_91e54_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_91e54_row1_col4" class="data row1 col4" >A+</td>
#       <td id="T_91e54_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_91e54_row1_col6" class="data row1 col6" >A+</td>
#       <td id="T_91e54_row1_col7" class="data row1 col7" >10.000000</td>
#       <td id="T_91e54_row1_col8" class="data row1 col8" >A-</td>
#       <td id="T_91e54_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_91e54_row1_col10" class="data row1 col10" >A+</td>
#       <td id="T_91e54_row1_col11" class="data row1 col11" >10.000000</td>
#       <td id="T_91e54_row1_col12" class="data row1 col12" >A-</td>
#       <td id="T_91e54_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_91e54_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_91e54_row1_col15" class="data row1 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_91e54_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_91e54_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_91e54_row2_col1" class="data row2 col1" >90002</td>
#       <td id="T_91e54_row2_col2" class="data row2 col2" >国防科技大学</td>
#       <td id="T_91e54_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_91e54_row2_col4" class="data row2 col4" >A+</td>
#       <td id="T_91e54_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_91e54_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_91e54_row2_col7" class="data row2 col7" >20.000000</td>
#       <td id="T_91e54_row2_col8" class="data row2 col8" >B+</td>
#       <td id="T_91e54_row2_col9" class="data row2 col9" >4.000000</td>
#       <td id="T_91e54_row2_col10" class="data row2 col10" >A+</td>
#       <td id="T_91e54_row2_col11" class="data row2 col11" >20.000000</td>
#       <td id="T_91e54_row2_col12" class="data row2 col12" >B+</td>
#       <td id="T_91e54_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_91e54_row2_col14" class="data row2 col14" >True</td>
#       <td id="T_91e54_row2_col15" class="data row2 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_91e54_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_91e54_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_91e54_row3_col1" class="data row3 col1" >10001</td>
#       <td id="T_91e54_row3_col2" class="data row3 col2" >北京大学</td>
#       <td id="T_91e54_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_91e54_row3_col4" class="data row3 col4" >A</td>
#       <td id="T_91e54_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_91e54_row3_col6" class="data row3 col6" >A+</td>
#       <td id="T_91e54_row3_col7" class="data row3 col7" >3.000000</td>
#       <td id="T_91e54_row3_col8" class="data row3 col8" >A</td>
#       <td id="T_91e54_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_91e54_row3_col10" class="data row3 col10" >A+</td>
#       <td id="T_91e54_row3_col11" class="data row3 col11" >3.000000</td>
#       <td id="T_91e54_row3_col12" class="data row3 col12" >A</td>
#       <td id="T_91e54_row3_col13" class="data row3 col13" >True</td>
#       <td id="T_91e54_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_91e54_row3_col15" class="data row3 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_91e54_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_91e54_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_91e54_row4_col1" class="data row4 col1" >10003</td>
#       <td id="T_91e54_row4_col2" class="data row4 col2" >清华大学</td>
#       <td id="T_91e54_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_91e54_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_91e54_row4_col5" class="data r

# %%
nbhelper.highlight_columns(good_university_major_df[pd.notna(good_university_major_df['计算机科学与技术-评选结果'])].reset_index(),['计算机科学与技术-排名', '计算机科学与技术-评选结果'])
# Out:
# <style type="text/css">
# #T_f8a00_row0_col5, #T_f8a00_row0_col6, #T_f8a00_row1_col5, #T_f8a00_row1_col6, #T_f8a00_row2_col5, #T_f8a00_row2_col6, #T_f8a00_row3_col5, #T_f8a00_row3_col6, #T_f8a00_row4_col5, #T_f8a00_row4_col6, #T_f8a00_row5_col5, #T_f8a00_row5_col6, #T_f8a00_row6_col5, #T_f8a00_row6_col6, #T_f8a00_row7_col5, #T_f8a00_row7_col6, #T_f8a00_row8_col5, #T_f8a00_row8_col6, #T_f8a00_row9_col5, #T_f8a00_row9_col6, #T_f8a00_row10_col5, #T_f8a00_row10_col6, #T_f8a00_row11_col5, #T_f8a00_row11_col6, #T_f8a00_row12_col5, #T_f8a00_row12_col6, #T_f8a00_row13_col5, #T_f8a00_row13_col6, #T_f8a00_row14_col5, #T_f8a00_row14_col6, #T_f8a00_row15_col5, #T_f8a00_row15_col6, #T_f8a00_row16_col5, #T_f8a00_row16_col6, #T_f8a00_row17_col5, #T_f8a00_row17_col6, #T_f8a00_row18_col5, #T_f8a00_row18_col6, #T_f8a00_row19_col5, #T_f8a00_row19_col6, #T_f8a00_row20_col5, #T_f8a00_row20_col6, #T_f8a00_row21_col5, #T_f8a00_row21_col6, #T_f8a00_row22_col5, #T_f8a00_row22_col6, #T_f8a00_row23_col5, #T_f8a00_row23_col6, #T_f8a00_row24_col5, #T_f8a00_row24_col6, #T_f8a00_row25_col5, #T_f8a00_row25_col6, #T_f8a00_row26_col5, #T_f8a00_row26_col6, #T_f8a00_row27_col5, #T_f8a00_row27_col6, #T_f8a00_row28_col5, #T_f8a00_row28_col6, #T_f8a00_row29_col5, #T_f8a00_row29_col6, #T_f8a00_row30_col5, #T_f8a00_row30_col6, #T_f8a00_row31_col5, #T_f8a00_row31_col6, #T_f8a00_row32_col5, #T_f8a00_row32_col6, #T_f8a00_row33_col5, #T_f8a00_row33_col6, #T_f8a00_row34_col5, #T_f8a00_row34_col6, #T_f8a00_row35_col5, #T_f8a00_row35_col6, #T_f8a00_row36_col5, #T_f8a00_row36_col6, #T_f8a00_row37_col5, #T_f8a00_row37_col6, #T_f8a00_row38_col5, #T_f8a00_row38_col6 {
#   background-color: yellow;
# }
# </style>
# <table id="T_f8a00">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8a00_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_f8a00_level0_col1" class="col_heading level0 col1" >学校代码</th>
#       <th id="T_f8a00_level0_col2" class="col_heading level0 col2" >学校名称</th>
#       <th id="T_f8a00_level0_col3" class="col_heading level0 col3" >软件工程-排名</th>
#       <th id="T_f8a00_level0_col4" class="col_heading level0 col4" >软件工程-评选结果</th>
#       <th id="T_f8a00_level0_col5" class="col_heading level0 col5" >计算机科学与技术-排名</th>
#       <th id="T_f8a00_level0_col6" class="col_heading level0 col6" >计算机科学与技术-评选结果</th>
#       <th id="T_f8a00_level0_col7" class="col_heading level0 col7" >大数据管理与应用-排名</th>
#       <th id="T_f8a00_level0_col8" class="col_heading level0 col8" >大数据管理与应用-评选结果</th>
#       <th id="T_f8a00_level0_col9" class="col_heading level0 col9" >物联网工程-排名</th>
#       <th id="T_f8a00_level0_col10" class="col_heading level0 col10" >物联网工程-评选结果</th>
#       <th id="T_f8a00_level0_col11" class="col_heading level0 col11" >人工智能-排名</th>
#       <th id="T_f8a00_level0_col12" class="col_heading level0 col12" >人工智能-评选结果</th>
#       <th id="T_f8a00_level0_col13" class="col_heading level0 col13" >是否211大学</th>
#       <th id="T_f8a00_level0_col14" class="col_heading level0 col14" >是否985大学</th>
#       <th id="T_f8a00_level0_col15" class="col_heading level0 col15" >是否双一流大学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8a00_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8a00_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_f8a00_row0_col1" class="data row0 col1" >10006</td>
#       <td id="T_f8a00_row0_col2" class="data row0 col2" >北京航空航天大学</td>
#       <td id="T_f8a00_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_f8a00_row0_col4" class="data row0 col4" >A+</td>
#       <td id="T_f8a00_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_f8a00_row0_col6" class="data row0 col6" >A</td>
#       <td id="T_f8a00_row0_col7" class="data row0 col7" >12.000000</td>
#       <td id="T_f8a00_row0_col8" class="data row0 col8" >B+</td>
#       <td id="T_f8a00_row0_col9" class="data row0 col9" >5.000000</td>
#       <td id="T_f8a00_row0_col10" class="data row0 col10" >A</td>
#       <td id="T_f8a00_row0_col11" class="data row0 col11" >12.000000</td>
#       <td id="T_f8a00_row0_col12" class="data row0 col12" >B+</td>
#       <td id="T_f8a00_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_f8a00_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_f8a00_row0_col15" class="data row0 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8a00_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8a00_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_f8a00_row1_col1" class="data row1 col1" >10335</td>
#       <td id="T_f8a00_row1_col2" class="data row1 col2" >浙江大学</td>
#       <td id="T_f8a00_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_f8a00_row1_col4" class="data row1 col4" >A+</td>
#       <td id="T_f8a00_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_f8a00_row1_col6" class="data row1 col6" >A+</td>
#       <td id="T_f8a00_row1_col7" class="data row1 col7" >10.000000</td>
#       <td id="T_f8a00_row1_col8" class="data row1 col8" >A-</td>
#       <td id="T_f8a00_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_f8a00_row1_col10" class="data row1 col10" >A+</td>
#       <td id="T_f8a00_row1_col11" class="data row1 col11" >10.000000</td>
#       <td id="T_f8a00_row1_col12" class="data row1 col12" >A-</td>
#       <td id="T_f8a00_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_f8a00_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_f8a00_row1_col15" class="data row1 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8a00_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8a00_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_f8a00_row2_col1" class="data row2 col1" >10001</td>
#       <td id="T_f8a00_row2_col2" class="data row2 col2" >北京大学</td>
#       <td id="T_f8a00_row2_col3" class="data row2 col3" >4.000000</td>
#       <td id="T_f8a00_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_f8a00_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_f8a00_row2_col6" class="data row2 col6" >A+</td>
#       <td id="T_f8a00_row2_col7" class="data row2 col7" >3.000000</td>
#       <td id="T_f8a00_row2_col8" class="data row2 col8" >A</td>
#       <td id="T_f8a00_row2_col9" class="data row2 col9" >1.000000</td>
#       <td id="T_f8a00_row2_col10" class="data row2 col10" >A+</td>
#       <td id="T_f8a00_row2_col11" class="data row2 col11" >3.000000</td>
#       <td id="T_f8a00_row2_col12" class="data row2 col12" >A</td>
#       <td id="T_f8a00_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_f8a00_row2_col14" class="data row2 col14" >True</td>
#       <td id="T_f8a00_row2_col15" class="data row2 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8a00_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8a00_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_f8a00_row3_col1" class="data row3 col1" >10003</td>
#       <td id="T_f8a00_row3_col2" class="data row3 col2" >清华大学</td>
#       <td id="T_f8a00_row3_col3" class="data row3 col3" >5.000000</td>
#       <td id="T_f8a00_row3_col4" class="data row3 col4" >A</td>
#       <td id="T_f8a00_row3_col5" class="data row3 col5" >2.000000</td>
#       <td id="T_f8a00_row3_col6" class="data row3 col6" >A+</td>
#       <td id="T_f8a00_row3_col7" class="data row3 col7" >4.000000</td>
#       <td id="T_f8a00_row3_col8" class="data row3 col8" >A</td>
#       <td id="T_f8a00_row3_col9" class="data row3 col9" >2.000000</td>
#       <td id="T_f8a00_row3_col10" class="data row3 col10" >A+</td>
#       <td id="T_f8a00_row3_col11" class="data row3 col11" >4.000000</td>
#       <td id="T_f8a00_row3_col12" class="data row3 col12" >A</td>
#       <td id="T_f8a00_row3_col13" class="data row3 col13" >True</td>
#       <td id="T_f8a00_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_f8a00_row3_col15" class="data row3 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8a00_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8a00_row4_col0" class="data ro

# %%
nbhelper.highlight_columns(good_university_major_df[pd.notna(good_university_major_df['大数据管理与应用-评选结果'])].reset_index(),['大数据管理与应用-排名', '大数据管理与应用-评选结果'])
# Out:
# <style type="text/css">
# #T_9ba9a_row0_col7, #T_9ba9a_row0_col8, #T_9ba9a_row1_col7, #T_9ba9a_row1_col8, #T_9ba9a_row2_col7, #T_9ba9a_row2_col8, #T_9ba9a_row3_col7, #T_9ba9a_row3_col8, #T_9ba9a_row4_col7, #T_9ba9a_row4_col8, #T_9ba9a_row5_col7, #T_9ba9a_row5_col8, #T_9ba9a_row6_col7, #T_9ba9a_row6_col8, #T_9ba9a_row7_col7, #T_9ba9a_row7_col8, #T_9ba9a_row8_col7, #T_9ba9a_row8_col8, #T_9ba9a_row9_col7, #T_9ba9a_row9_col8, #T_9ba9a_row10_col7, #T_9ba9a_row10_col8, #T_9ba9a_row11_col7, #T_9ba9a_row11_col8, #T_9ba9a_row12_col7, #T_9ba9a_row12_col8, #T_9ba9a_row13_col7, #T_9ba9a_row13_col8, #T_9ba9a_row14_col7, #T_9ba9a_row14_col8, #T_9ba9a_row15_col7, #T_9ba9a_row15_col8, #T_9ba9a_row16_col7, #T_9ba9a_row16_col8, #T_9ba9a_row17_col7, #T_9ba9a_row17_col8, #T_9ba9a_row18_col7, #T_9ba9a_row18_col8, #T_9ba9a_row19_col7, #T_9ba9a_row19_col8, #T_9ba9a_row20_col7, #T_9ba9a_row20_col8, #T_9ba9a_row21_col7, #T_9ba9a_row21_col8, #T_9ba9a_row22_col7, #T_9ba9a_row22_col8, #T_9ba9a_row23_col7, #T_9ba9a_row23_col8, #T_9ba9a_row24_col7, #T_9ba9a_row24_col8, #T_9ba9a_row25_col7, #T_9ba9a_row25_col8, #T_9ba9a_row26_col7, #T_9ba9a_row26_col8, #T_9ba9a_row27_col7, #T_9ba9a_row27_col8, #T_9ba9a_row28_col7, #T_9ba9a_row28_col8, #T_9ba9a_row29_col7, #T_9ba9a_row29_col8, #T_9ba9a_row30_col7, #T_9ba9a_row30_col8 {
#   background-color: yellow;
# }
# </style>
# <table id="T_9ba9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ba9a_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_9ba9a_level0_col1" class="col_heading level0 col1" >学校代码</th>
#       <th id="T_9ba9a_level0_col2" class="col_heading level0 col2" >学校名称</th>
#       <th id="T_9ba9a_level0_col3" class="col_heading level0 col3" >软件工程-排名</th>
#       <th id="T_9ba9a_level0_col4" class="col_heading level0 col4" >软件工程-评选结果</th>
#       <th id="T_9ba9a_level0_col5" class="col_heading level0 col5" >计算机科学与技术-排名</th>
#       <th id="T_9ba9a_level0_col6" class="col_heading level0 col6" >计算机科学与技术-评选结果</th>
#       <th id="T_9ba9a_level0_col7" class="col_heading level0 col7" >大数据管理与应用-排名</th>
#       <th id="T_9ba9a_level0_col8" class="col_heading level0 col8" >大数据管理与应用-评选结果</th>
#       <th id="T_9ba9a_level0_col9" class="col_heading level0 col9" >物联网工程-排名</th>
#       <th id="T_9ba9a_level0_col10" class="col_heading level0 col10" >物联网工程-评选结果</th>
#       <th id="T_9ba9a_level0_col11" class="col_heading level0 col11" >人工智能-排名</th>
#       <th id="T_9ba9a_level0_col12" class="col_heading level0 col12" >人工智能-评选结果</th>
#       <th id="T_9ba9a_level0_col13" class="col_heading level0 col13" >是否211大学</th>
#       <th id="T_9ba9a_level0_col14" class="col_heading level0 col14" >是否985大学</th>
#       <th id="T_9ba9a_level0_col15" class="col_heading level0 col15" >是否双一流大学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ba9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ba9a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_9ba9a_row0_col1" class="data row0 col1" >10006</td>
#       <td id="T_9ba9a_row0_col2" class="data row0 col2" >北京航空航天大学</td>
#       <td id="T_9ba9a_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_9ba9a_row0_col4" class="data row0 col4" >A+</td>
#       <td id="T_9ba9a_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_9ba9a_row0_col6" class="data row0 col6" >A</td>
#       <td id="T_9ba9a_row0_col7" class="data row0 col7" >12.000000</td>
#       <td id="T_9ba9a_row0_col8" class="data row0 col8" >B+</td>
#       <td id="T_9ba9a_row0_col9" class="data row0 col9" >5.000000</td>
#       <td id="T_9ba9a_row0_col10" class="data row0 col10" >A</td>
#       <td id="T_9ba9a_row0_col11" class="data row0 col11" >12.000000</td>
#       <td id="T_9ba9a_row0_col12" class="data row0 col12" >B+</td>
#       <td id="T_9ba9a_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_9ba9a_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_9ba9a_row0_col15" class="data row0 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9ba9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ba9a_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9ba9a_row1_col1" class="data row1 col1" >10335</td>
#       <td id="T_9ba9a_row1_col2" class="data row1 col2" >浙江大学</td>
#       <td id="T_9ba9a_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_9ba9a_row1_col4" class="data row1 col4" >A+</td>
#       <td id="T_9ba9a_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_9ba9a_row1_col6" class="data row1 col6" >A+</td>
#       <td id="T_9ba9a_row1_col7" class="data row1 col7" >10.000000</td>
#       <td id="T_9ba9a_row1_col8" class="data row1 col8" >A-</td>
#       <td id="T_9ba9a_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_9ba9a_row1_col10" class="data row1 col10" >A+</td>
#       <td id="T_9ba9a_row1_col11" class="data row1 col11" >10.000000</td>
#       <td id="T_9ba9a_row1_col12" class="data row1 col12" >A-</td>
#       <td id="T_9ba9a_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_9ba9a_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_9ba9a_row1_col15" class="data row1 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9ba9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9ba9a_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_9ba9a_row2_col1" class="data row2 col1" >90002</td>
#       <td id="T_9ba9a_row2_col2" class="data row2 col2" >国防科技大学</td>
#       <td id="T_9ba9a_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_9ba9a_row2_col4" class="data row2 col4" >A+</td>
#       <td id="T_9ba9a_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_9ba9a_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_9ba9a_row2_col7" class="data row2 col7" >20.000000</td>
#       <td id="T_9ba9a_row2_col8" class="data row2 col8" >B+</td>
#       <td id="T_9ba9a_row2_col9" class="data row2 col9" >4.000000</td>
#       <td id="T_9ba9a_row2_col10" class="data row2 col10" >A+</td>
#       <td id="T_9ba9a_row2_col11" class="data row2 col11" >20.000000</td>
#       <td id="T_9ba9a_row2_col12" class="data row2 col12" >B+</td>
#       <td id="T_9ba9a_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_9ba9a_row2_col14" class="data row2 col14" >True</td>
#       <td id="T_9ba9a_row2_col15" class="data row2 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9ba9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9ba9a_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9ba9a_row3_col1" class="data row3 col1" >10001</td>
#       <td id="T_9ba9a_row3_col2" class="data row3 col2" >北京大学</td>
#       <td id="T_9ba9a_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_9ba9a_row3_col4" class="data row3 col4" >A</td>
#       <td id="T_9ba9a_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_9ba9a_row3_col6" class="data row3 col6" >A+</td>
#       <td id="T_9ba9a_row3_col7" class="data row3 col7" >3.000000</td>
#       <td id="T_9ba9a_row3_col8" class="data row3 col8" >A</td>
#       <td id="T_9ba9a_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_9ba9a_row3_col10" class="data row3 col10" >A+</td>
#       <td id="T_9ba9a_row3_col11" class="data row3 col11" >3.000000</td>
#       <td id="T_9ba9a_row3_col12" class="data row3 col12" >A</td>
#       <td id="T_9ba9a_row3_col13" class="data row3 col13" >True</td>
#       <td id="T_9ba9a_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_9ba9a_row3_col15" class="data row3 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9ba9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9ba9a_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_9ba9a_row4_col1" class="data row4 col1" >10003</td>
#       <td id="T_9ba9a_row4_col2" class="data row4 col2" >清华大学</td>
#       <td id="T_9ba9a_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_9ba9a_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_9ba9a_row4_col5" class="data r

# %%
nbhelper.highlight_columns(good_university_major_df[pd.notna(good_university_major_df['物联网工程-评选结果'])].reset_index(),['物联网工程-排名', '物联网工程-评选结果'])
# Out:
# <style type="text/css">
# #T_efead_row0_col9, #T_efead_row0_col10, #T_efead_row1_col9, #T_efead_row1_col10, #T_efead_row2_col9, #T_efead_row2_col10, #T_efead_row3_col9, #T_efead_row3_col10, #T_efead_row4_col9, #T_efead_row4_col10, #T_efead_row5_col9, #T_efead_row5_col10, #T_efead_row6_col9, #T_efead_row6_col10, #T_efead_row7_col9, #T_efead_row7_col10, #T_efead_row8_col9, #T_efead_row8_col10, #T_efead_row9_col9, #T_efead_row9_col10, #T_efead_row10_col9, #T_efead_row10_col10, #T_efead_row11_col9, #T_efead_row11_col10, #T_efead_row12_col9, #T_efead_row12_col10, #T_efead_row13_col9, #T_efead_row13_col10, #T_efead_row14_col9, #T_efead_row14_col10, #T_efead_row15_col9, #T_efead_row15_col10, #T_efead_row16_col9, #T_efead_row16_col10, #T_efead_row17_col9, #T_efead_row17_col10, #T_efead_row18_col9, #T_efead_row18_col10, #T_efead_row19_col9, #T_efead_row19_col10, #T_efead_row20_col9, #T_efead_row20_col10, #T_efead_row21_col9, #T_efead_row21_col10, #T_efead_row22_col9, #T_efead_row22_col10, #T_efead_row23_col9, #T_efead_row23_col10, #T_efead_row24_col9, #T_efead_row24_col10, #T_efead_row25_col9, #T_efead_row25_col10, #T_efead_row26_col9, #T_efead_row26_col10, #T_efead_row27_col9, #T_efead_row27_col10, #T_efead_row28_col9, #T_efead_row28_col10, #T_efead_row29_col9, #T_efead_row29_col10, #T_efead_row30_col9, #T_efead_row30_col10, #T_efead_row31_col9, #T_efead_row31_col10, #T_efead_row32_col9, #T_efead_row32_col10, #T_efead_row33_col9, #T_efead_row33_col10, #T_efead_row34_col9, #T_efead_row34_col10, #T_efead_row35_col9, #T_efead_row35_col10, #T_efead_row36_col9, #T_efead_row36_col10, #T_efead_row37_col9, #T_efead_row37_col10, #T_efead_row38_col9, #T_efead_row38_col10 {
#   background-color: yellow;
# }
# </style>
# <table id="T_efead">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efead_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_efead_level0_col1" class="col_heading level0 col1" >学校代码</th>
#       <th id="T_efead_level0_col2" class="col_heading level0 col2" >学校名称</th>
#       <th id="T_efead_level0_col3" class="col_heading level0 col3" >软件工程-排名</th>
#       <th id="T_efead_level0_col4" class="col_heading level0 col4" >软件工程-评选结果</th>
#       <th id="T_efead_level0_col5" class="col_heading level0 col5" >计算机科学与技术-排名</th>
#       <th id="T_efead_level0_col6" class="col_heading level0 col6" >计算机科学与技术-评选结果</th>
#       <th id="T_efead_level0_col7" class="col_heading level0 col7" >大数据管理与应用-排名</th>
#       <th id="T_efead_level0_col8" class="col_heading level0 col8" >大数据管理与应用-评选结果</th>
#       <th id="T_efead_level0_col9" class="col_heading level0 col9" >物联网工程-排名</th>
#       <th id="T_efead_level0_col10" class="col_heading level0 col10" >物联网工程-评选结果</th>
#       <th id="T_efead_level0_col11" class="col_heading level0 col11" >人工智能-排名</th>
#       <th id="T_efead_level0_col12" class="col_heading level0 col12" >人工智能-评选结果</th>
#       <th id="T_efead_level0_col13" class="col_heading level0 col13" >是否211大学</th>
#       <th id="T_efead_level0_col14" class="col_heading level0 col14" >是否985大学</th>
#       <th id="T_efead_level0_col15" class="col_heading level0 col15" >是否双一流大学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efead_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efead_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_efead_row0_col1" class="data row0 col1" >10006</td>
#       <td id="T_efead_row0_col2" class="data row0 col2" >北京航空航天大学</td>
#       <td id="T_efead_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_efead_row0_col4" class="data row0 col4" >A+</td>
#       <td id="T_efead_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_efead_row0_col6" class="data row0 col6" >A</td>
#       <td id="T_efead_row0_col7" class="data row0 col7" >12.000000</td>
#       <td id="T_efead_row0_col8" class="data row0 col8" >B+</td>
#       <td id="T_efead_row0_col9" class="data row0 col9" >5.000000</td>
#       <td id="T_efead_row0_col10" class="data row0 col10" >A</td>
#       <td id="T_efead_row0_col11" class="data row0 col11" >12.000000</td>
#       <td id="T_efead_row0_col12" class="data row0 col12" >B+</td>
#       <td id="T_efead_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_efead_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_efead_row0_col15" class="data row0 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efead_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efead_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_efead_row1_col1" class="data row1 col1" >10335</td>
#       <td id="T_efead_row1_col2" class="data row1 col2" >浙江大学</td>
#       <td id="T_efead_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_efead_row1_col4" class="data row1 col4" >A+</td>
#       <td id="T_efead_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_efead_row1_col6" class="data row1 col6" >A+</td>
#       <td id="T_efead_row1_col7" class="data row1 col7" >10.000000</td>
#       <td id="T_efead_row1_col8" class="data row1 col8" >A-</td>
#       <td id="T_efead_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_efead_row1_col10" class="data row1 col10" >A+</td>
#       <td id="T_efead_row1_col11" class="data row1 col11" >10.000000</td>
#       <td id="T_efead_row1_col12" class="data row1 col12" >A-</td>
#       <td id="T_efead_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_efead_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_efead_row1_col15" class="data row1 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efead_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efead_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_efead_row2_col1" class="data row2 col1" >90002</td>
#       <td id="T_efead_row2_col2" class="data row2 col2" >国防科技大学</td>
#       <td id="T_efead_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_efead_row2_col4" class="data row2 col4" >A+</td>
#       <td id="T_efead_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_efead_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_efead_row2_col7" class="data row2 col7" >20.000000</td>
#       <td id="T_efead_row2_col8" class="data row2 col8" >B+</td>
#       <td id="T_efead_row2_col9" class="data row2 col9" >4.000000</td>
#       <td id="T_efead_row2_col10" class="data row2 col10" >A+</td>
#       <td id="T_efead_row2_col11" class="data row2 col11" >20.000000</td>
#       <td id="T_efead_row2_col12" class="data row2 col12" >B+</td>
#       <td id="T_efead_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_efead_row2_col14" class="data row2 col14" >True</td>
#       <td id="T_efead_row2_col15" class="data row2 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efead_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efead_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_efead_row3_col1" class="data row3 col1" >10001</td>
#       <td id="T_efead_row3_col2" class="data row3 col2" >北京大学</td>
#       <td id="T_efead_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_efead_row3_col4" class="data row3 col4" >A</td>
#       <td id="T_efead_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_efead_row3_col6" class="data row3 col6" >A+</td>
#       <td id="T_efead_row3_col7" class="data row3 col7" >3.000000</td>
#       <td id="T_efead_row3_col8" class="data row3 col8" >A</td>
#       <td id="T_efead_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_efead_row3_col10" class="data row3 col10" >A+</td>
#       <td id="T_efead_row3_col11" class="data row3 col11" >3.000000</td>
#       <td id="T_efead_row3_col12" class="data row3 col12" >A</td>
#       <td id="T_efead_row3_col13" class="data row3 col13" >True</td>
#       <td id="T_efead_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_efead_row3_col15" class="data row3 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_efead_level0_row4" class="row_heading level0 row4" >4</th>

# %%
nbhelper.highlight_columns(good_university_major_df[pd.notna(good_university_major_df['人工智能-评选结果'])].reset_index(),['人工智能-排名', '人工智能-评选结果'])
# Out:
# <style type="text/css">
# #T_8a9ee_row0_col11, #T_8a9ee_row0_col12, #T_8a9ee_row1_col11, #T_8a9ee_row1_col12, #T_8a9ee_row2_col11, #T_8a9ee_row2_col12, #T_8a9ee_row3_col11, #T_8a9ee_row3_col12, #T_8a9ee_row4_col11, #T_8a9ee_row4_col12, #T_8a9ee_row5_col11, #T_8a9ee_row5_col12, #T_8a9ee_row6_col11, #T_8a9ee_row6_col12, #T_8a9ee_row7_col11, #T_8a9ee_row7_col12, #T_8a9ee_row8_col11, #T_8a9ee_row8_col12, #T_8a9ee_row9_col11, #T_8a9ee_row9_col12, #T_8a9ee_row10_col11, #T_8a9ee_row10_col12, #T_8a9ee_row11_col11, #T_8a9ee_row11_col12, #T_8a9ee_row12_col11, #T_8a9ee_row12_col12, #T_8a9ee_row13_col11, #T_8a9ee_row13_col12, #T_8a9ee_row14_col11, #T_8a9ee_row14_col12, #T_8a9ee_row15_col11, #T_8a9ee_row15_col12, #T_8a9ee_row16_col11, #T_8a9ee_row16_col12, #T_8a9ee_row17_col11, #T_8a9ee_row17_col12, #T_8a9ee_row18_col11, #T_8a9ee_row18_col12, #T_8a9ee_row19_col11, #T_8a9ee_row19_col12, #T_8a9ee_row20_col11, #T_8a9ee_row20_col12, #T_8a9ee_row21_col11, #T_8a9ee_row21_col12, #T_8a9ee_row22_col11, #T_8a9ee_row22_col12, #T_8a9ee_row23_col11, #T_8a9ee_row23_col12, #T_8a9ee_row24_col11, #T_8a9ee_row24_col12, #T_8a9ee_row25_col11, #T_8a9ee_row25_col12, #T_8a9ee_row26_col11, #T_8a9ee_row26_col12, #T_8a9ee_row27_col11, #T_8a9ee_row27_col12, #T_8a9ee_row28_col11, #T_8a9ee_row28_col12, #T_8a9ee_row29_col11, #T_8a9ee_row29_col12, #T_8a9ee_row30_col11, #T_8a9ee_row30_col12 {
#   background-color: yellow;
# }
# </style>
# <table id="T_8a9ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9ee_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_8a9ee_level0_col1" class="col_heading level0 col1" >学校代码</th>
#       <th id="T_8a9ee_level0_col2" class="col_heading level0 col2" >学校名称</th>
#       <th id="T_8a9ee_level0_col3" class="col_heading level0 col3" >软件工程-排名</th>
#       <th id="T_8a9ee_level0_col4" class="col_heading level0 col4" >软件工程-评选结果</th>
#       <th id="T_8a9ee_level0_col5" class="col_heading level0 col5" >计算机科学与技术-排名</th>
#       <th id="T_8a9ee_level0_col6" class="col_heading level0 col6" >计算机科学与技术-评选结果</th>
#       <th id="T_8a9ee_level0_col7" class="col_heading level0 col7" >大数据管理与应用-排名</th>
#       <th id="T_8a9ee_level0_col8" class="col_heading level0 col8" >大数据管理与应用-评选结果</th>
#       <th id="T_8a9ee_level0_col9" class="col_heading level0 col9" >物联网工程-排名</th>
#       <th id="T_8a9ee_level0_col10" class="col_heading level0 col10" >物联网工程-评选结果</th>
#       <th id="T_8a9ee_level0_col11" class="col_heading level0 col11" >人工智能-排名</th>
#       <th id="T_8a9ee_level0_col12" class="col_heading level0 col12" >人工智能-评选结果</th>
#       <th id="T_8a9ee_level0_col13" class="col_heading level0 col13" >是否211大学</th>
#       <th id="T_8a9ee_level0_col14" class="col_heading level0 col14" >是否985大学</th>
#       <th id="T_8a9ee_level0_col15" class="col_heading level0 col15" >是否双一流大学</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8a9ee_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8a9ee_row0_col1" class="data row0 col1" >10006</td>
#       <td id="T_8a9ee_row0_col2" class="data row0 col2" >北京航空航天大学</td>
#       <td id="T_8a9ee_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_8a9ee_row0_col4" class="data row0 col4" >A+</td>
#       <td id="T_8a9ee_row0_col5" class="data row0 col5" >5.000000</td>
#       <td id="T_8a9ee_row0_col6" class="data row0 col6" >A</td>
#       <td id="T_8a9ee_row0_col7" class="data row0 col7" >12.000000</td>
#       <td id="T_8a9ee_row0_col8" class="data row0 col8" >B+</td>
#       <td id="T_8a9ee_row0_col9" class="data row0 col9" >5.000000</td>
#       <td id="T_8a9ee_row0_col10" class="data row0 col10" >A</td>
#       <td id="T_8a9ee_row0_col11" class="data row0 col11" >12.000000</td>
#       <td id="T_8a9ee_row0_col12" class="data row0 col12" >B+</td>
#       <td id="T_8a9ee_row0_col13" class="data row0 col13" >True</td>
#       <td id="T_8a9ee_row0_col14" class="data row0 col14" >True</td>
#       <td id="T_8a9ee_row0_col15" class="data row0 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8a9ee_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8a9ee_row1_col1" class="data row1 col1" >10335</td>
#       <td id="T_8a9ee_row1_col2" class="data row1 col2" >浙江大学</td>
#       <td id="T_8a9ee_row1_col3" class="data row1 col3" >2.000000</td>
#       <td id="T_8a9ee_row1_col4" class="data row1 col4" >A+</td>
#       <td id="T_8a9ee_row1_col5" class="data row1 col5" >3.000000</td>
#       <td id="T_8a9ee_row1_col6" class="data row1 col6" >A+</td>
#       <td id="T_8a9ee_row1_col7" class="data row1 col7" >10.000000</td>
#       <td id="T_8a9ee_row1_col8" class="data row1 col8" >A-</td>
#       <td id="T_8a9ee_row1_col9" class="data row1 col9" >3.000000</td>
#       <td id="T_8a9ee_row1_col10" class="data row1 col10" >A+</td>
#       <td id="T_8a9ee_row1_col11" class="data row1 col11" >10.000000</td>
#       <td id="T_8a9ee_row1_col12" class="data row1 col12" >A-</td>
#       <td id="T_8a9ee_row1_col13" class="data row1 col13" >True</td>
#       <td id="T_8a9ee_row1_col14" class="data row1 col14" >True</td>
#       <td id="T_8a9ee_row1_col15" class="data row1 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8a9ee_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_8a9ee_row2_col1" class="data row2 col1" >90002</td>
#       <td id="T_8a9ee_row2_col2" class="data row2 col2" >国防科技大学</td>
#       <td id="T_8a9ee_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_8a9ee_row2_col4" class="data row2 col4" >A+</td>
#       <td id="T_8a9ee_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_8a9ee_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_8a9ee_row2_col7" class="data row2 col7" >20.000000</td>
#       <td id="T_8a9ee_row2_col8" class="data row2 col8" >B+</td>
#       <td id="T_8a9ee_row2_col9" class="data row2 col9" >4.000000</td>
#       <td id="T_8a9ee_row2_col10" class="data row2 col10" >A+</td>
#       <td id="T_8a9ee_row2_col11" class="data row2 col11" >20.000000</td>
#       <td id="T_8a9ee_row2_col12" class="data row2 col12" >B+</td>
#       <td id="T_8a9ee_row2_col13" class="data row2 col13" >True</td>
#       <td id="T_8a9ee_row2_col14" class="data row2 col14" >True</td>
#       <td id="T_8a9ee_row2_col15" class="data row2 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8a9ee_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_8a9ee_row3_col1" class="data row3 col1" >10001</td>
#       <td id="T_8a9ee_row3_col2" class="data row3 col2" >北京大学</td>
#       <td id="T_8a9ee_row3_col3" class="data row3 col3" >4.000000</td>
#       <td id="T_8a9ee_row3_col4" class="data row3 col4" >A</td>
#       <td id="T_8a9ee_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_8a9ee_row3_col6" class="data row3 col6" >A+</td>
#       <td id="T_8a9ee_row3_col7" class="data row3 col7" >3.000000</td>
#       <td id="T_8a9ee_row3_col8" class="data row3 col8" >A</td>
#       <td id="T_8a9ee_row3_col9" class="data row3 col9" >1.000000</td>
#       <td id="T_8a9ee_row3_col10" class="data row3 col10" >A+</td>
#       <td id="T_8a9ee_row3_col11" class="data row3 col11" >3.000000</td>
#       <td id="T_8a9ee_row3_col12" class="data row3 col12" >A</td>
#       <td id="T_8a9ee_row3_col13" class="data row3 col13" >True</td>
#       <td id="T_8a9ee_row3_col14" class="data row3 col14" >True</td>
#       <td id="T_8a9ee_row3_col15" class="data row3 col15" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8a9ee_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_8a9ee_row4_col1" class="data row4 col1" >10003</td>
#       <td id="T_8a9ee_row4_col2" class="data row4 col2" >清华大学</td>
#       <td id="T_8a9ee_row4_col3" class="data row4 col3" >5.000000</td>
#       <td id="T_8a9ee_row4_col4" class="data row

# %%
best_high_tech_university_df = good_university_major_df[pd.notna(good_university_major_df['人工智能-评选结果']) & 
                                                        pd.notna(good_university_major_df['计算机科学与技术-评选结果']) & 
                                                        pd.notna(good_university_major_df['大数据管理与应用-评选结果']) &
                                                        pd.notna(good_university_major_df['物联网工程-评选结果']) &
                                                        pd.notna(good_university_major_df['人工智能-评选结果']) &
                                                        pd.notna(good_university_major_df['软件工程-评选结果'])
                                                       ].reset_index(drop=True)

best_high_tech_university_df = pd.merge(best_high_tech_university_df, university_211_df, how='inner', left_on='学校名称', right_on='名称')
best_high_tech_university_df = best_high_tech_university_df.drop(columns=['名称','学校代码'])
best_high_tech_university_df = nbhelper.ahead_df_columns(best_high_tech_university_df, ['学校名称', '排名', '所在地', '生源质量分'])
best_high_tech_university_df = best_high_tech_university_df.astype({'排名': 'int32', 
                                                                    '软件工程-排名': 'int32',
                                                                    '计算机科学与技术-排名': 'int32',
                                                                    '大数据管理与应用-排名': 'int32',
                                                                    '物联网工程-排名': 'int32', 
                                                                    '人工智能-排名': 'int32'
                                                                   })
best_high_tech_university_df = best_high_tech_university_df.sort_values(by=['排名', '软件工程-排名', '计算机科学与技术-排名', '大数据管理与应用-排名', '人工智能-排名','物联网工程-排名'])
best_high_tech_university_df.reset_index(drop=True)
# Out:
#         学校名称  排名  所在地 生源质量分  软件工程-排名 软件工程-评选结果  计算机科学与技术-排名 计算机科学与技术-评选结果  \
# 0       清华大学   1   北京   100        5         A            2            A+
# 1       北京大学   2   北京  96.4        4         A            1            A+
# 2   中国科学技术大学   3   安徽  92.1       15        A-           17            A-
# 3       复旦大学   4   上海  91.5       23        B+           31            B+
# 4     上海交通大学   6   上海  90.5       13        A-            8             A
# 5       南京大学   7   江苏  88.4        7         A            9             A
# 6       浙江大学   9   浙江  86.3        2        A+            3            A+
# 7       南开大学  11   天津  85.9       35         B           27            B+
# 8   北京航空航天大学  12   北京  85.4        1        A+            5             A
# 9       武汉大学  15   湖北  84.4        8         A           18            A-
# 10    西安交通大学  17   陕西  83.6       48         B           20            A-
# 11      天津大学  18   天津  82.5        9        A-           28            B+
# 12    北京理工大学  20   北京  82.1       19        B+           13            A-
# 13      东南大学  21   江苏  81.8       24        B+           33            B+
# 14      中山大学  23   广东  81.1       47         B           41            B+
# 15    华东师范大学  25   上海  79.4        6         A           32            B+
# 16   哈尔滨工业大学  26  黑龙江  78.2       11        A-            7             A
# 17      厦门大学  28   福建  77.9       43         B           38            B+
# 18    西北工业大学  30   陕西  77.1       31        B+           21            A-
# 19    大连理工大学  33   辽宁  75.8       21        B+           29            B+
# 20      四川大学  35   四川  75.7       16        A-           43            B+
# 21    电子科技大学  36   四川  75.4       29        B+           11             A
# 22    华南理工大学  38   广东  74.8       27        B+           42            B+
# 23      吉林大学  39   吉林  74.4       22        B+           15            A-
# 24      重庆大学  42   重庆  73.8       28        B+           44            B+
# 25      山东大学  45   山东  73.4       26        B+           39            B+
#
#     大数据管理与应用-排名 大数据管理与应用-评选结果  物联网工程-排名 物联网工程-评选结果  人工智能-排名 人工智能-评选结果  \
# 0             4             A         2         A+        4         A
# 1             3             A         1         A+        3         A
# 2            27             B        17         A-       27         B
# 3             7            A-        31         B+        7        A-
# 4             8            A-         8          A        8        A-
# 5             9            A-         9          A        9        A-
# 6            10            A-         3         A+       10        A-
# 7            23             B        27         B+       23         B
# 8            12            B+         5          A       12        B+
# 9            29             B        18         A-       29         B
# 10           11            A-        20         A-       11        A-
# 11           14            B+        28         B+       14        B+
# 12           13            B+        13         A-       13        B+
# 13            5             A        33         B+        5         A
# 14           30             B        41         B+       30         B
# 15           25             B        32         B+       25         B
# 16           24             B         7          A       24         B
# 17           28             B        38         B+       28         B
# 18           19            B+        21         A-       19        B+
# 19           33            B-        29         B+       33        B-
# 20           60             C        43         B+       60         C
# 21            1            A+        11          A        1        A+
# 22           31             B        42         B+       31         B
# 23           15            B+        15         A-       15        B+
# 24           39            B-        44         B+       39        B-
# 25           37            B-        39         B+       37        B-
#
#     是否211大学  是否985大学  是否双一流大学
# 0      True     True     True
# 1      True     True     True
# 2      True     True     True
# 3      True     True     True
# 4      True     True     True
# 5      True     True     True
# 6      True     True     True
# 7      True     True     True
# 8      True     True     True
# 9      True     True     True
# 10     True     True     True
# 11     True     True     True
# 12     True     True     True
# 13     True     True     True
# 14     True     True     True
# 15     True     True     True
# 16     True     True     True
# 17     True     True     True
# 18     True     True     True
# 19     True     True     True
# 20     True     True     True
# 21     True     True     True
# 22     True     True     True
# 23     True     True     True
# 24     True     True     True
# 25     True     True     True

# %%
area_dist_high_tech_df = best_high_tech_university_df[['学校名称', '所在地']].groupby(by=['所在地']).count()
area_dist_high_tech_df.plot(kind='barh', title='高新技术 - 大学区域分布', xticks = range(0, area_dist_high_tech_df.max()[0] + 1), xlabel='区域', figsize=(25,10))
# Out:
# <AxesSubplot:title={'center':'高新技术 - 大学区域分布'}, ylabel='区域'>
