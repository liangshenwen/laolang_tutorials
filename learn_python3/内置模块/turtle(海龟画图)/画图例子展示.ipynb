# %% [markdown]
# https://docs.python.org/zh-cn/3/library/turtle.html#
#
#
# 海龟绘图很适合用来引导孩子学习编程。 最初来自于 Wally Feurzeig, Seymour Papert 和 Cynthia Solomon 于 1967 年所创造的 Logo 编程语言。
#
# 请想象绘图区有一只机器海龟，起始位置在 x-y 平面的 (0, 0) 点。先执行 import turtle，再执行 turtle.forward(15)，它将(在屏幕上)朝所面对的 x 轴正方向前进 15 像素，随着它的移动画出一条线段。再执行 turtle.right(25)，它将原地右转 25 度。
#
# https://realpython.com/beginners-guide-python-turtle/
# ![image.png](attachment:c5fc898d-e23d-41d2-a6f3-4724eef87234.png)

# %% [markdown]
# # 太阳花
# ![image.png](attachment:54e15a1a-0b04-45a8-907b-baec8c70f4d5.png)

# %%
# !python 太阳花.py

# %% [markdown]
# # 海龟比赛

# %%
# !python 海龟比赛.py
# Out:
# The result of the die roll for player one is:
# 2
# The number of steps for player one will be:
# 40
# The result of the die roll for player two is:
# 1
# The number of steps for play two will be:
# 20
# The result of the die roll for player one is:
# 6
# The number of steps for player one will be:
# 120
# The result of the die roll for player two is:
# 4
# The number of steps for play two will be:
# 80
# The result of the die roll for player one is:
# 3
# The number of steps for player one will be:
# 60
# The result of the die roll for player two is:
# 5
# The number of steps for play two will be:
# 100
# The result of the die roll for player one is:
# 1
# The number of steps for player one will be:
# 20
# The result of the die roll for player two is:
# 5
# The number of steps for play two will be:
# 100
# The result of the die roll for player one is:
# 5
# The number of steps for player one will be:
# 100
# The result of the die roll for player two is:
# 6
# The number of steps for play two will be:
# 120
# The result of the die roll for player one is:
# 3
# The number of steps for player one will be:
# 60
# The result of the die roll for player two is:
# 3
# The number of steps for play two will be:
# 60
# The result of the die roll for player one is:
# 2
# The number of steps for player one will be:
# 40
# The result of the die roll for player two is:
# 5
# The number of steps for play two will be:
# 100
# Player Two Wins!

# %% [markdown]
# # 爱心

# %%
# !python 爱心.py

# %% [markdown]
# ## 旋转的风车
# https://blog.csdn.net/m0_48190198/article/details/123278861
#
# ![image.png](attachment:d3f85162-ec48-4f03-890b-92db391caa62.png)
