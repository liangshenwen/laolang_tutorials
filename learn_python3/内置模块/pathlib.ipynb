# %% [markdown]
# https://docs.python.org/zh-cn/3/library/pathlib.html
#
# ![image.png](attachment:200e18f0-c67b-4fb0-9491-7931ee6c5b49.png)
#
# 该模块提供表示文件系统路径的类，其语义适用于不同的操作系统。路径类被分为提供纯计算操作而没有 I/O 的 纯路径，以及从纯路径继承而来但提供 I/O 操作的 具体路径。
#
# 如果以前从未用过此模块，或不确定哪个类适合完成任务，那要用的可能就是 Path。

# %%
from pathlib import Path
p = Path('.')
[x for x in p.iterdir() if x.is_dir()]
# Out:
# [WindowsPath('.ipynb_checkpoints'),
#  WindowsPath('asyncio'),
#  WindowsPath('bandclass'),
#  WindowsPath('how_to_log'),
#  WindowsPath('turtle(海龟画图)'),
#  WindowsPath('性能优化')]

# %%
p = Path('.')
for child in p.iterdir(): 
    print(child)
# Out:
# .ipynb_checkpoints
# asyncio
# bandclass
# chain_map_test.py
# collections_chainmap.ipynb
# collections_counter.ipynb
# collections_defaultdict.ipynb
# collections_deque.ipynb
# collections_namedtuple.ipynb
# collections_userxxx.ipynb
# deque_moving_average.py
# deque_roundrobin.py
# doctest.ipynb
# echo.py
# exception.ipynb
# filter_map_zip.ipynb
# hamlet.txt
# hello.txt
# helloworld.py
# how_to_log
# keywords.ipynb
# mmap.ipynb
# os_path.ipynb
# pathlib.ipynb
# pretty_print.ipynb
# tail_test.txt
# turtle(海龟画图)
# __main__ Top-level code environment.ipynb
# 函数式编程_functools.ipynb
# 函数式编程_itertools_排列组合迭代器.ipynb
# 函数式编程_itertools_无穷迭代器.ipynb
# 函数式编程_itertools_根据最短输入序列长度停止的迭代器.ipynb
# 函数式编程_more_itertools.ipynb
# 函数式编程_operator.ipynb
# 参数解析(argument parser).ipynb
# 性能优化
# 数学_statistics.ipynb
